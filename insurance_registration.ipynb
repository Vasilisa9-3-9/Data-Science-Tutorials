# %%
#import Libraries 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
#import the data
insurance_data = pd.read_csv("insurance.csv")
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#select which columns are going to be used 
x_not_2D  = insurance_data.loc[:,'age'].values
y_not_2D = insurance_data.loc[:,'charges'].values

#plot the graph based on the selected columns 
plt.scatter(x_not_2D,y_not_2D,color = 'b')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.show()

# %%
#create a 2D array of the selected x and y values
x_2D = insurance_data['age'].values.reshape(-1,1)
y_2D = insurance_data['charges'].values

# %%
#fit and predict the data 
linear_model = LinearRegression()
linear_model.fit(x_2D,y_2D)
y_predict = simple_model.predict(x_2D)

# %%
#plot a new reshaped data, with a displayed line of the best fit
plt.figure()
sns.scatterplot(data = insurance_data, x = 'age', y = 'charges')
plt.plot(x_2D, y_predict)
plt.show()
plt.close()
